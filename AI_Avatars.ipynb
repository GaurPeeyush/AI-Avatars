# %%
#@markdown Check type of GPU and VRAM available.
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader
# Out:
# Tesla T4, 15360 MiB, 15101 MiB

# %% [markdown]
# https://github.com/ShivamShrirao/diffusers/tree/main/examples/dreambooth

# %% [markdown]
# ## Install Requirements

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/examples/dreambooth/train_dreambooth.py
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/scripts/convert_diffusers_to_original_stable_diffusion.py
# %pip install -qq git+https://github.com/ShivamShrirao/diffusers
# %pip install -q -U --pre triton
# %pip install -q accelerate transformers ftfy bitsandbytes==0.35.0 gradio natsort safetensors xformers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 5.9 MB/s eta 0:00:00
#   Building wheel for diffusers (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 2.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.0.1+cu118 requires triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64", but you have triton 2.1.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 22.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 82.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.0/167.0 MB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 79.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 31.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 16.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 9.1 MB/s eta 0:00:00
#   Building wheel for ffmpy (setup.py) ... done

# %%
#@title Login to HuggingFace 🤗

#@markdown You need to accept the model license before downloading or using the Stable Diffusion weights. Please, visit the [model card](https://huggingface.co/runwayml/stable-diffusion-v1-5), read the license and tick the checkbox if you agree. You have to be a registered user in 🤗 Hugging Face Hub, and you'll also need to use an access token for the code to work.
# https://huggingface.co/settings/tokens
# !mkdir -p ~/.huggingface
HUGGINGFACE_TOKEN = "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" #@param {type:"string"}
# !echo -n "{HUGGINGFACE_TOKEN}" > ~/.huggingface/token

# %% [markdown]
# ## Settings and run

# %%
#@markdown If model weights should be saved directly in google drive (takes around 4-5 GB).
save_to_gdrive = True #@param {type:"boolean"}
if save_to_gdrive:
    from google.colab import drive
    drive.mount('/content/drive')

#@markdown Name/Path of the initial model.
MODEL_NAME = "runwayml/stable-diffusion-v1-5" #@param {type:"string"}

#@markdown Enter the directory name to save model at.

OUTPUT_DIR = "stable_diffusion_weights/" #@param {type:"string"}
if save_to_gdrive:
    OUTPUT_DIR = "/content/drive/MyDrive/" + OUTPUT_DIR
else:
    OUTPUT_DIR = "/content/" + OUTPUT_DIR

print(f"[*] Weights will be saved at {OUTPUT_DIR}")

# !mkdir -p $OUTPUT_DIR
# Out:
# Mounted at /content/drive
# [*] Weights will be saved at /content/drive/MyDrive/stable_diffusion_weights/

# %% [markdown]
# # Start Training
#
# Use the table below to choose the best flags based on your memory and speed requirements. Tested on Tesla T4 GPU.
#
#
# | `fp16` | `train_batch_size` | `gradient_accumulation_steps` | `gradient_checkpointing` | `use_8bit_adam` | GB VRAM usage | Speed (it/s) |
# | ---- | ------------------ | ----------------------------- | ----------------------- | --------------- | ---------- | ------------ |
# | fp16 | 1                  | 1                             | TRUE                    | TRUE            | 9.92       | 0.93         |
# | no   | 1                  | 1                             | TRUE                    | TRUE            | 10.08      | 0.42         |
# | fp16 | 2                  | 1                             | TRUE                    | TRUE            | 10.4       | 0.66         |
# | fp16 | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 1.14         |
# | no   | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 0.49         |
# | fp16 | 1                  | 2                             | TRUE                    | TRUE            | 11.56      | 1            |
# | fp16 | 2                  | 1                             | FALSE                   | TRUE            | 13.67      | 0.82         |
# | fp16 | 1                  | 2                             | FALSE                   | TRUE            | 13.7       | 0.83          |
# | fp16 | 1                  | 1                             | TRUE                    | FALSE           | 15.79      | 0.77         |

# %% [markdown]
# Add `--gradient_checkpointing` flag for around 9.92 GB VRAM usage.
#
# remove `--use_8bit_adam` flag for full precision. Requires 15.79 GB with `--gradient_checkpointing` else 17.8 GB.
#
# remove `--train_text_encoder` flag to reduce memory usage further, degrades output quality.

# %%
# You can also add multiple concepts here. Try tweaking `--max_train_steps` accordingly.

concepts_list = [
    {
        "instance_prompt":      "photo of Peeyush person",
        "class_prompt":         "photo of a Human",
        "instance_data_dir":    "/content/data/AImodel",
        "class_data_dir":       "/content/data/person"
    },
#     {
#         "instance_prompt":      "photo of ukj person",
#         "class_prompt":         "photo of a person",
#         "instance_data_dir":    "/content/data/ukj",
#         "class_data_dir":       "/content/data/person"
#     }
]

# `class_data_dir` contains regularization images
import json
import os
for c in concepts_list:
    os.makedirs(c["instance_data_dir"], exist_ok=True)

with open("concepts_list.json", "w") as f:
    json.dump(concepts_list, f, indent=4)

# %%
#@markdown Upload your images by running this cell.

#@markdown OR

#@markdown You can use the file manager on the left panel to upload (drag and drop) to each `instance_data_dir` (it uploads faster). You can also upload your own class images in `class_data_dir` if u don't wanna generate with SD.

import os
from google.colab import files
import shutil

for c in concepts_list:
    print(f"Uploading instance images for `{c['instance_prompt']}`")
    uploaded = files.upload()
    for filename in uploaded.keys():
        dst_path = os.path.join(c['instance_data_dir'], filename)
        shutil.move(filename, dst_path)

# %%
# !python3 train_dreambooth.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --pretrained_vae_name_or_path="stabilityai/sd-vae-ft-mse" \
  --output_dir=$OUTPUT_DIR \
  --revision="fp16" \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --seed=1337 \
  --resolution=512 \
  --train_batch_size=1 \
  --train_text_encoder \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=1e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --num_class_images=50 \
  --sample_batch_size=4 \
  --max_train_steps=1000 \
  --save_interval=1000 \
  --save_sample_prompt="photo of Peeyush person" \
  --concepts_list="concepts_list.json"

# Reduce the `--save_interval` to lower than `--max_train_steps` to save weights from intermediate steps.
# `--save_sample_prompt` can be same as `--instance_prompt` to generate intermediate samples (saved along with weights in samples directory).
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:105: UserWarning: /usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.28.0.1'), PosixPath('http'), PosixPath('8013')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https'), PosixPath('//colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/gpu-t4-s-199x8rtxoue5a --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//ipykernel.pylab.backend_inline'), PosixPath('module')}
#   warn(
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 118
# CUDA SETUP: Loading binary /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so...
# 2023-09-25 10:21:48.720632: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_hf_folder.py:98: UserWarning: A token has been found in `/root/.huggingface/token`. This is the old path where tokens were stored. The new location is `/root/.cache/huggingface/token` which is configurable using `HF_HOME` environment variable. Your token has been copied to this new location. You can now safely delete the old token file manually or use `huggingface-cli logout`.
#   warnings.warn(
# Downloading (…)lve/main/config.json: 100% 547/547 [00:00<00:00, 3.65MB/s]
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:05<00:00, 64.8MB/s]
# Downloading (…)p16/model_index.json: 100% 543/543 [00:00<00:00, 3.93MB/s]
# vae/diffusion_pytorch_model.safetensors not found
# Fetching 15 files:   0% 0/15 [00:00<?, ?it/s]
# Downloading (…)tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 8.92MB/s]
#
# Downloading (…)_checker/config.json: 100% 4.70k/4.70k [00:00<00:00, 23.6MB/s]
#
# Downloading (…)cial_tokens_map.json: 100% 472/472 [00:00<00:00, 3.35MB/s]
#
# Downloading (…)okenizer_config.json: 100% 822/822 [00:00<00:00, 5.38MB/s]
#
# Downloading (…)_encoder/config.json: 100% 636/636 [00:00<00:00, 4.92MB/s]
#
# Downloading (…)tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
# Downloading (…)rocessor_config.json: 100% 342/342 [00:00<00:00, 2.12MB/s]
# Fetching 15 files:   7% 1/15 [00:00<00:10,  1.32it/s]
#
# Downloading (…)cc2/unet/config.json: 100% 806/806 [00:00<00:00, 5.53MB/s]
#
#
# Downloading (…)cheduler_config.json: 100% 307/307 [00:00<00:00, 1.87MB/s]
#
#
# Downloading (…)9cc2/vae/config.json: 100% 609/609 [00:00<00:00, 3.50MB/s]
# Downloading (…)tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 15.2MB/s]
#
# Downloading (…)on_pytorch_model.bin:   0% 0.00/1.72G [00:00<?, ?B/s]
#
# Downloading pytorch_model.bin:   0% 0.00/246M [00:00<?, ?B/s]
#
#
# Downloading pytorch_model.bin:   0% 0.00/608M [00:00<?, ?B/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   0% 0.00/167M [00:00<?, ?B/s]
# Downloading (…)on_pytorch_model.bin:   1% 10.5M/1.72G [00:00<00:16, 102MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:   6% 10.5M/167M [00:00<00:01, 82.8MB/s]
#
# Downloading pytorch_model.bin:   4% 10.5M/246M [00:00<00:03, 72.1MB/s]
# Downloading (…)on_pytorch_model.bin:   2% 31.5M/1.72G [00:00<00:10, 158MB/s]
#
#
# Downloading pytorch_model.bin:   2% 10.5M/608M [00:00<00:11, 51.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  13% 21.0M/167M [00:00<00:01, 81.8MB/s]
#
# Downloading pytorch_model.bin:   9% 21.0M/246M [00:00<00:03, 74.6MB/s]
#
#
# Downloading pytorch_model.bin:   3% 21.0M/608M [00:00<00:09, 63.3MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  19% 31.5M/167M [00:00<00:01, 84.2MB/s]
#
# Downloading pytorch_model.bin:  13% 31.5M/246M [00:00<00:02, 81.0MB/s]
# Downloading (…)on_pytorch_model.bin:   3% 52.4M/1.72G [00:00<00:15, 105MB/s]
#
#
# Downloading pytorch_model.bin:   5% 31.5M/608M [00:00<00:07, 76.7MB/s]
#
# Downloading pytorch_model.bin:  17% 41.9M/246M [00:00<00:02, 86.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  31% 52.4M/167M [00:00<00:01, 98.6MB/s]
# Downloading (…)on_pytorch_model.bin:   4% 73.4M/1.72G [00:00<00:15, 104MB/s]
#
#
# Downloading pytorch_model.bin:   9% 52.4M/608M [00:00<00:06, 88.7MB/s]
#
# Downloading pytorch_model.bin:  26% 62.9M/246M [00:00<00:01, 92.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  44% 73.4M/167M [00:00<00:00, 105MB/s]
#
#
# Downloading pytorch_model.bin:  10% 62.9M/608M [00:00<00:05, 92.1MB/s]
# Downloading (…)on_pytorch_model.bin:   5% 94.4M/1.72G [00:00<00:13, 116MB/s]
#
# Downloading pytorch_model.bin:  30% 73.4M/246M [00:00<00:01, 94.1MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  50% 83.9M/167M [00:00<00:00, 93.6MB/s]
#
# Downloading pytorch_model.bin:  34% 83.9M/246M [00:00<00:01, 87.0MB/s]
#
#
# Downloading pytorch_model.bin:  14% 83.9M/608M [00:01<00:05, 89.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  56% 94.4M/167M [00:01<00:00, 87.3MB/s]
# Downloading (…)on_pytorch_model.bin:   7% 115M/1.72G [00:01<00:17, 91.5MB/s]
#
# Downloading pytorch_model.bin:  38% 94.4M/246M [00:01<00:02, 74.4MB/s]
#
#
# Downloading pytorch_model.bin:  16% 94.4M/608M [00:01<00:06, 81.0MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  63% 105M/167M [00:01<00:00, 82.3MB/s]
# Downloading (…)on_pytorch_model.bin:   7% 126M/1.72G [00:01<00:19, 83.4MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  69% 115M/167M [00:01<00:00, 69.7MB/s]
#
# Downloading pytorch_model.bin:  43% 105M/246M [00:01<00:02, 57.6MB/s]
#
#
# Downloading pytorch_model.bin:  17% 105M/608M [00:01<00:08, 59.5MB/s]
# Downloading (…)on_pytorch_model.bin:   8% 136M/1.72G [00:01<00:24, 65.2MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  75% 126M/167M [00:01<00:00, 52.6MB/s]
#
# Downloading pytorch_model.bin:  47% 115M/246M [00:01<00:02, 46.6MB/s]
#
#
# Downloading pytorch_model.bin:  19% 115M/608M [00:01<00:10, 48.4MB/s]
# Downloading (…)on_pytorch_model.bin:   9% 147M/1.72G [00:01<00:29, 52.9MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  81% 136M/167M [00:01<00:00, 56.3MB/s]
#
# Downloading pytorch_model.bin:  51% 126M/246M [00:01<00:02, 48.8MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  88% 147M/167M [00:01<00:00, 64.0MB/s]
#
#
# Downloading pytorch_model.bin:  21% 126M/608M [00:02<00:10, 47.2MB/s]
# Downloading (…)on_pytorch_model.bin:   9% 157M/1.72G [00:02<00:29, 53.1MB/s]
#
# Downloading pytorch_model.bin:  55% 136M/246M [00:02<00:02, 53.3MB/s]
#
#
# Downloading pytorch_model.bin:  22% 136M/608M [00:02<00:09, 52.4MB/s]
#
#
#
# Downloading (…)on_pytorch_model.bin:  94% 157M/167M [00:02<00:00, 55.1MB/s]
# Downloading (…)on_pytorch_model.bin:  10% 168M/1.72G [00:02<00:29, 52.0MB/s]
#
#
# Downloading pytorch_model.bin:  24% 147M/608M [00:02<00:07, 60.9MB/s]
#
# Downloading (…)on_pytorch_model.bin: 100% 167M/167M [00:02<00:00, 69.8MB/s]
#
#
# Downloading pytorch_model.bin:  64% 157M/246M [00:02<00:01, 62.1MB/s]
#
#
# Downloading pytorch_model.bin:  28% 168M/608M [00:02<00:05, 78.3MB/s]
# Downloading (…)on_pytorch_model.bin:  11% 189M/1.72G [00:02<00:22, 66.5MB/s]
#
# Downloading pytorch_model.bin:  68% 168M/246M [00:02<00:01, 68.2MB/s]
# Downloading (…)on_pytorch_model.bin:  12% 210M/1.72G [00:02<00:17, 86.2MB/s]
#
#
# Downloading pytorch_model.bin:  31% 189M/608M [00:02<00:04, 92.3MB/s]
#
# Downloading pytorch_model.bin:  77% 189M/246M [00:02<00:00, 83.9MB/s]
# Downloading (…)on_pytorch_model.bin:  13% 231M/1.72G [00:02<00:14, 102MB/s]
#
#
# Downloading pytorch_model.bin:  33% 199M/608M [00:02<00:04, 92.3MB/s]
#
#
# Downloading pytorch_model.bin:  34% 210M/608M [00:02<00:04, 86.2MB/s]
#
# Downloading pytorch_model.bin:  85% 210M/246M [00:02<00:00, 87.6MB/s]
# Downloading (…)on_pytorch_model.bin:  15% 252M/1.72G [00:03<00:14, 99.4MB/s]
#
#
# Downloading pytorch_model.bin:  36% 220M/608M [00:03<00:04, 85.8MB/s]
#
# Downloading pytorch_model.bin:  89% 220M/246M [00:03<00:00, 85.0MB/s]
#
#
# Downloading pytorch_model.bin:  38% 231M/608M [00:03<00:04, 84.4MB/s]
#
# Downloading pytorch_model.bin:  94% 231M/246M [00:03<00:00, 83.5MB/s]
# Downloading (…)on_pytorch_model.bin:  16% 273M/1.72G [00:03<00:15, 92.7MB/s]
#
#
# Downloading pytorch_model.bin:  40% 241M/608M [00:03<00:04, 87.1MB/s]
#
# Downloading pytorch_model.bin:  98% 241M/246M [00:03<00:00, 81.3MB/s]
#
#
# Downloading pytorch_model.bin:  41% 252M/608M [00:03<00:04, 86.5MB/s]
# Downloading pytorch_model.bin: 100% 246M/246M [00:03<00:00, 70.1MB/s]
#
#
#
# Downloading pytorch_model.bin:  43% 262M/608M [00:03<00:04, 84.3MB/s]
# Downloading (…)on_pytorch_model.bin:  18% 304M/1.72G [00:03<00:15, 93.8MB/s]
#
#
# Downloading pytorch_model.bin:  47% 283M/608M [00:03<00:03, 97.4MB/s]
# Downloading (…)on_pytorch_model.bin:  19% 325M/1.72G [00:03<00:13, 101MB/s]
#
#
# Downloading pytorch_model.bin:  50% 304M/608M [00:03<00:02, 106MB/s]
# Downloading (…)on_pytorch_model.bin:  20% 346M/1.72G [00:03<00:12, 109MB/s]
#
#
# Downloading pytorch_model.bin:  53% 325M/608M [00:04<00:02, 111MB/s]
# Downloading (…)on_pytorch_model.bin:  21% 367M/1.72G [00:04<00:12, 112MB/s]
#
#
# Downloading pytorch_model.bin:  57% 346M/608M [00:04<00:02, 116MB/s]
# Downloading (…)on_pytorch_model.bin:  23% 388M/1.72G [00:04<00:11, 117MB/s]
#
#
# Downloading pytorch_model.bin:  60% 367M/608M [00:04<00:01, 124MB/s]
# Downloading (…)on_pytorch_model.bin:  24% 409M/1.72G [00:04<00:10, 126MB/s]
#
#
# Downloading pytorch_model.bin:  64% 388M/608M [00:04<00:01, 125MB/s]
# Downloading (…)on_pytorch_model.bin:  25% 430M/1.72G [00:04<00:09, 130MB/s]
# Downloading (…)on_pytorch_model.bin:  26% 451M/1.72G [00:04<00:09, 138MB/s]
#
#
# Downloading pytorch_model.bin:  67% 409M/608M [00:04<00:01, 123MB/s]
# Downloading (…)on_pytorch_model.bin:  27% 472M/1.72G [00:04<00:09, 134MB/s]
#
#
# Downloading pytorch_model.bin:  71% 430M/608M [00:04<00:01, 124MB/s]
# Downloading (…)on_pytorch_model.bin:  29% 493M/1.72G [00:05<00:09, 131MB/s]
#
#
# Downloading pytorch_model.bin:  74% 451M/608M [00:05<00:01, 124MB/s]
# Downloading (…)on_pytorch_model.bin:  30% 514M/1.72G [00:05<00:09, 124MB/s]
#
#
# Downloading pytorch_model.bin:  78% 472M/608M [00:05<00:01, 117MB/s]
# Downloading (…)on_pytorch_model.bin:  31% 535M/1.72G [00:05<00:09, 128MB/s]
#
#
# Downloading pytorch_model.bin:  81% 493M/608M [00:05<00:01, 112MB/s]
# Downloading (…)on_pytorch_model.bin:  32% 556M/1.72G [00:05<00:10, 114MB/s]
#
#
# Downloading pytorch_model.bin:  84% 514M/608M [00:05<00:00, 107MB/s]
# Downloading (…)on_pytorch_model.bin:  34% 577M/1.72G [00:05<00:08, 130MB/s]
# Downloading (…)on_pytorch_model.bin:  35% 598M/1.72G [00:05<00:08, 138MB/s]
#
#
# Downloading pytorch_model.bin:  88% 535M/608M [00:05<00:00, 113MB/s]
# Downloading (…)on_pytorch_model.bin:  36% 619M/1.72G [00:05<00:08, 135MB/s]
#
#
# Downloading pytorch_model.bin:  91% 556M/608M [00:05<00:00, 115MB/s]
# Downloading (…)on_pytorch_model.bin:  37% 640M/1.72G [00:06<00:07, 135MB/s]
#
#
# Downloading pytorch_model.bin:  95% 577M/608M [00:06<00:00, 116MB/s]
# Downloading (…)on_pytorch_model.bin:  38% 661M/1.72G [00:06<00:08, 122MB/s]
#
#
# Downloading pytorch_model.bin: 100% 608M/608M [00:06<00:00, 90.9MB/s]
# Fetching 15 files:  27% 4/15 [00:07<00:22,  2.05s/it]
# Downloading (…)on_pytorch_model.bin:  40% 682M/1.72G [00:06<00:12, 85.9MB/s]
# Downloading (…)on_pytorch_model.bin:  41% 713M/1.72G [00:06<00:08, 116MB/s]
# Downloading (…)on_pytorch_model.bin:  43% 734M/1.72G [00:07<00:07, 125MB/s]
# Downloading (…)on_pytorch_model.bin:  45% 765M/1.72G [00:07<00:06, 150MB/s]
# Downloading (…)on_pytorch_model.bin:  46% 786M/1.72G [00:07<00:05, 158MB/s]
# Downloading (…)on_pytorch_model.bin:  47% 807M/1.72G [00:07<00:05, 168MB/s]
# Downloading (…)on_pytorch_model.bin:  48% 828M/1.72G [00:07<00:05, 178MB/s]
# Downloading (…)on_pytorch_model.bin:  50% 860M/1.72G [00:07<00:04, 190MB/s]
# Downloading (…)on_pytorch_model.bin:  51% 881M/1.72G [00:07<00:04, 194MB/s]
# Downloading (…)on_pytorch_model.bin:  53% 912M/1.72G [00:07<00:03, 206MB/s]
# Downloading (…)on_pytorch_model.bin:  55% 944M/1.72G [00:08<00:03, 202MB/s]
# Downloading (…)on_pytorch_model.bin:  57% 975M/1.72G [00:08<00:03, 212MB/s]
# Downloading (…)on_pytorch_model.bin:  59% 1.01G/1.72G [00:08<00:03, 213MB/s]
# Downloading (…)on_pytorch_model.bin:  60% 1.04G/1.72G [00:08<00:02, 229MB/s]
# Downloading (…)on_pytorch_model.bin:  62% 1.07G/1.72G [00:08<00:02, 238MB/s]
# Downloading (…)on_pytorch_model.bin:  64% 1.10G/1.72G [00:08<00:02, 245MB/s]
# Downloading (…)on_pytorch_model.bin:  66% 1.13G/1.72G [00:08<00:02, 224MB/s]
# Downloading (…)on_pytorch_model.bin:  68% 1.16G/1.72G [00:09<00:02, 206MB/s]
# Downloading (…)on_pytorch_model.bin:  70% 1.20G/1.72G [00:09<00:02, 204MB/s]
# Downloading (…)on_pytorch_model.bin:  71% 1.23G/1.72G [00:09<00:02, 208MB/s]
# Downloading (…)on_pytorch_model.bin:  73% 1.26G/1.72G [00:09<00:02, 207MB/s]
# Downloading (…)on_pytorch_model.bin:  75% 1.29G/1.72G [00:09<00:02, 209MB/s]
# Downloading (…)on_pytorch_model.bin:  77% 1.32G/1.72G [00:09<00:01, 211MB/s]
# Downloading (…)on_pytorch_model.bin:  79% 1.35G/1.72G [00:09<00:01, 217MB/s]
# Downloading (…)on_pytorch_model.bin:  81% 1.38G/1.72G [00:10<00:01, 217MB/s]
# Downloading (…)on_pytorch_model.bin:  82% 1.42G/1.72G [00:11<00:04, 65.7MB/s]
# Downloading (…)on_pytorch_model.bin:  84% 1.44G/1.72G [00:11<00:03, 77.1MB/s]
# Downloading (…)on_pytorch_model.bin:  85% 1.46G/1.72G [00:11<00:02, 90.0MB/s]
# Downloading (…)on_pytorch_model.bin:  86% 1.48G/1.72G [00:11<00:02, 105MB/s]
# Downloading (…)on_pytorch_model.bin:  87% 1.50G/1.72G [00:13<00:06, 32.8MB/s]
# Downloading (…)on_pytorch_model.bin:  88% 1.52G/1.72G [00:13<00:04, 42.3MB/s]
# Downloading (…)on_pytorch_model.bin:  90% 1.55G/1.72G [00:13<00:02, 61.5MB/s]
# Downloading (…)on_pytorch_model.bin:  92% 1.58G/1.72G [00:13<00:01, 84.0MB/s]
# Downloading (…)on_pytorch_model.bin:  94% 1.61G/1.72G [00:13<00:00, 108MB/s]
# Downloading (…)on_pytorch_model.bin:  96% 1.65G/1.72G [00:14<00:00, 132MB/s]
# Downloading (…)on_pytorch_model.bin:  98% 1.68G/1.72G [00:14<00:00, 152MB/s]
# Downloading (…)on_pytorch_model.bin: 100% 1.72G/1.72G [00:14<00:00, 120MB/s]
# Fetching 15 files: 100% 15/15 [00:15<00:00,  1.03s/it]
# /usr/local/lib/python3.10/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# 09/25/2023 10:22:25 - INFO - __main__ - Number of class images to sample: 50.
# Generating class images: 100% 13/13 [02:51<00:00, 13.20s/it]
# /usr/local/lib/python3.10/dist-packages/diffusers/configuration_utils.py:203: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# Downloading (…)cheduler_config.json: 100% 308/308 [00:00<00:00, 2.06MB/s]
# Caching latents: 100% 50/50 [00:10<00:00,  4.86it/s]
# 09/25/2023 10:25:45 - INFO - __main__ - ***** Running training *****
# 09/25/2023 10:25:45 - INFO - __main__ -   Num examples = 50
# 09/25/2023 10:25:45 - INFO - __main__ -   Num batches each epoch = 50
# 09/25/2023 10:25:45 - INFO - __main__ -   Num Epochs = 20
# 09/25/2023 10:25:45 - INFO - __main__ -   Instantaneous batch size per device = 1
# 09/25/2023 10:25:45 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 09/25/2023 10:25:45 - INFO - __main__ -   Gradient Accumulation steps = 1
# 09/25/2023 10:25:45 - INFO - __main__ -   Total optimization steps = 1000
# Steps: 100% 1000/1000 [12:18<00:00,  1.37it/s, loss=0.26, lr=1e-6]vae/diffusion_pytorch_model.safetensors not found
# /usr/local/lib/python3.10/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#
# Generating samples:   0% 0/4 [00:00<?, ?it/s]
# Generating samples:  25% 1/4 [00:05<00:16,  5.46s/it]
# Generating samples:  50% 2/4 [00:09<00:09,  4.54s/it]
# Generating samples:  75% 3/4 [00:14<00:04,  4.68s/it]
# Generating samples: 100% 4/4 [00:18<00:00,  4.59s/it]
# [*] Weights saved at /content/drive/MyDrive/stable_diffusion_weights/1000
# Steps: 100% 1000/1000 [13:22<00:00,  1.25it/s, loss=0.26, lr=1e-6]

# %%
#@markdown Specify the weights directory to use (leave blank for latest)
WEIGHTS_DIR = "" #@param {type:"string"}
if WEIGHTS_DIR == "":
    from natsort import natsorted
    from glob import glob
    import os
    WEIGHTS_DIR = natsorted(glob(OUTPUT_DIR + os.sep + "*"))[-1]
print(f"[*] WEIGHTS_DIR={WEIGHTS_DIR}")
# Out:
# [*] WEIGHTS_DIR=/content/drive/MyDrive/stable_diffusion_weights/1000

# %%
#@markdown Run to generate a grid of preview images from the last saved weights.
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

weights_folder = OUTPUT_DIR
folders = sorted([f for f in os.listdir(weights_folder) if f != "0"], key=lambda x: int(x))

row = len(folders)
col = len(os.listdir(os.path.join(weights_folder, folders[0], "samples")))
scale = 4
fig, axes = plt.subplots(row, col, figsize=(col*scale, row*scale), gridspec_kw={'hspace': 0, 'wspace': 0})

for i, folder in enumerate(folders):
    folder_path = os.path.join(weights_folder, folder)
    image_folder = os.path.join(folder_path, "samples")
    images = [f for f in os.listdir(image_folder)]
    for j, image in enumerate(images):
        if row == 1:
            currAxes = axes[j]
        else:
            currAxes = axes[i, j]
        if i == 0:
            currAxes.set_title(f"Image {j}")
        if j == 0:
            currAxes.text(-0.1, 0.5, folder, rotation=0, va='center', ha='center', transform=currAxes.transAxes)
        image_path = os.path.join(image_folder, image)
        img = mpimg.imread(image_path)
        currAxes.imshow(img, cmap='gray')
        currAxes.axis('off')

plt.tight_layout()
plt.savefig('grid.png', dpi=72)

# %% [markdown]
# ## Convert weights to ckpt to use in web UIs like AUTOMATIC1111.

# %%
#@markdown Run conversion.
ckpt_path = WEIGHTS_DIR + "/model.ckpt"

half_arg = ""
#@markdown  Whether to convert to fp16, takes half the space (2GB).
fp16 = True #@param {type: "boolean"}
if fp16:
    half_arg = "--half"
# !python convert_diffusers_to_original_stable_diffusion.py --model_path $WEIGHTS_DIR  --checkpoint_path $ckpt_path $half_arg
print(f"[*] Converted ckpt saved at {ckpt_path}")
# Out:
# Reshaping encoder.mid.attn_1.q.weight for SD format
# Reshaping encoder.mid.attn_1.k.weight for SD format
# Reshaping encoder.mid.attn_1.v.weight for SD format
# Reshaping encoder.mid.attn_1.proj_out.weight for SD format
# Reshaping decoder.mid.attn_1.q.weight for SD format
# Reshaping decoder.mid.attn_1.k.weight for SD format
# Reshaping decoder.mid.attn_1.v.weight for SD format
# Reshaping decoder.mid.attn_1.proj_out.weight for SD format
# [*] Converted ckpt saved at /content/drive/MyDrive/stable_diffusion_weights/1000/model.ckpt

# %% [markdown]
# ## Inference

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline, DDIMScheduler
from IPython.display import display

model_path = WEIGHTS_DIR             # If you want to use previously trained model saved in gdrive, replace this with the full path of model in gdrive

pipe = StableDiffusionPipeline.from_pretrained(model_path, safety_checker=None, torch_dtype=torch.float16).to("cuda")
pipe.scheduler = DDIMScheduler.from_config(pipe.scheduler.config)
pipe.enable_xformers_memory_efficient_attention()
g_cuda = None
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 118
# CUDA SETUP: Loading binary /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so...
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:105: UserWarning: /usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//172.28.0.1'), PosixPath('http'), PosixPath('8013')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https'), PosixPath('//colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/gpu-t4-s-199x8rtxoue5a --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('module'), PosixPath('//ipykernel.pylab.backend_inline')}
#   warn(
# /usr/local/lib/python3.10/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .

# %%
#@markdown Can set random seed here for reproducibility.
g_cuda = torch.Generator(device='cuda')
seed = -1 #@param {type:"number"}
g_cuda.manual_seed(seed)

# %%
#@title Run for generating images.

prompt = "photo of Peeyush Person" #@param {type:"string"}
negative_prompt = "weird face, weird hands, shirtless" #@param {type:"string"}
num_samples = 4 #@param {type:"number"}
guidance_scale = 7 #@param {type:"number"}
num_inference_steps = 30 #@param {type:"number"}
height = 512 #@param {type:"number"}
width = 512 #@param {type:"number"}

with autocast("cuda"), torch.inference_mode():
    images = pipe(
        prompt,
        height=height,
        width=width,
        negative_prompt=negative_prompt,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=g_cuda
    ).images

for img in images:
    display(img)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
#@markdown Run Gradio UI for generating images.
import gradio as gr

def inference(prompt, negative_prompt, num_samples, height=512, width=512, num_inference_steps=50, guidance_scale=7.5):
    with torch.autocast("cuda"), torch.inference_mode():
        return pipe(
                prompt, height=int(height), width=int(width),
                negative_prompt=negative_prompt,
                num_images_per_prompt=int(num_samples),
                num_inference_steps=int(num_inference_steps), guidance_scale=guidance_scale,
                generator=g_cuda
            ).images

with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            prompt = gr.Textbox(label="Prompt", value="photo of zwx dog in a bucket")
            negative_prompt = gr.Textbox(label="Negative Prompt", value="")
            run = gr.Button(value="Generate")
            with gr.Row():
                num_samples = gr.Number(label="Number of Samples", value=4)
                guidance_scale = gr.Number(label="Guidance Scale", value=7.5)
            with gr.Row():
                height = gr.Number(label="Height", value=512)
                width = gr.Number(label="Width", value=512)
            num_inference_steps = gr.Slider(label="Steps", value=24)
        with gr.Column():
            gallery = gr.Gallery()

    run.click(inference, inputs=[prompt, negative_prompt, num_samples, height, width, num_inference_steps, guidance_scale], outputs=gallery)

demo.launch(debug=True)

# %%
#@title (Optional) Delete diffuser and old weights and only keep the ckpt to free up drive space.

#@markdown [ ! ] Caution, Only execute if you are sure u want to delete the diffuser format weights and only use the ckpt.
import shutil
from glob import glob
import os
for f in glob(OUTPUT_DIR+os.sep+"*"):
    if f != WEIGHTS_DIR:
        shutil.rmtree(f)
        print("Deleted", f)
for f in glob(WEIGHTS_DIR+"/*"):
    if not f.endswith(".ckpt") or not f.endswith(".json"):
        try:
            shutil.rmtree(f)
        except NotADirectoryError:
            continue
        print("Deleted", f)

# %%
#@title Free runtime memory
exit()
